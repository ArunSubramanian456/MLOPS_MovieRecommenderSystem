# %% [markdown]
# ## Data Processing Part3

# %% [markdown]
# data sources
#
# https://en.wikipedia.org/wiki/List_of_American_films_of_2018
#
# https://en.wikipedia.org/wiki/List_of_American_films_of_2019
#
# https://en.wikipedia.org/wiki/List_of_American_films_of_2020

# %%
# !pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in c:\users\aruns\anaconda3\lib\site-packages (from tmdbv3api) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aruns\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aruns\anaconda3\lib\site-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aruns\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aruns\anaconda3\lib\site-packages (from requests->tmdbv3api) (2024.8.30)
# Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in c:\users\aruns\anaconda3\lib\site-packages (6.0.1)

# %%
import pandas as pd
import numpy as np
import ast

import matplotlib.pyplot as ply
import seaborn as sns

from tmdbv3api import TMDb
from tmdbv3api import Movie
import json
import requests

import yaml

# %%
# Function to get genres
def get_genre(x, tmdb, tmdb_movie): #pass in the title of the movies
    try:
        genres = []
        result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
        movie_id = result[0].id #we will match the "id" with the "title"
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
        data_json = response.json() # we will then convert it to a json file
        if data_json['genres']: #in the json file we will only need to extract the "genre"
            genre_str = " " 
            for i in range(0,len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
            return genre_str.join(genres)
        else:
            np.NaN # we will return the results but if we don't find anything we will consider it as a missing value
    except Exception as e:
        return np.NaN


# Function to get directors name
def get_director(x):
    if " (director)" in x: # we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: # we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    elif " (director[" in x:
        return x.split(" (director[")[0]
    elif " (director/" in x:
        return x.split(" (director/")[0] # we are getting "director/screenplay"
        
# Functions to get actor names
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
    
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])


# Final data processing function
def ProcessData(df1, df2, df3, df4, config_file = "config.yml"):
    
    # Append all 4 dataframes together
    df = pd.concat([df1, df2, df3, df4], axis = 0, ignore_index=True)

    df = df.dropna(subset=['Title'])

    if df.Title.str.contains('closure of theaters caused by the COVID-19 pandemic').any():
        df = df[~(df.Title.str.contains('closure of theaters caused by the COVID-19 pandemic'))]

    if df.Title.str.contains('Canadian theatrical release').any():
        df = df[~(df.Title.str.contains('Canadian theatrical release'))]

    if df.Title.str.contains('Dating and New York').any():
        df = df[(df.Title!= 'Dating and New York')]

    if df.Title.str.contains('Apollo 10').any():
        df = df[~(df.Title.str.contains('Apollo 10'))]


    # Get TMDB API key
    # get your API Key here: https://www.themoviedb.org/settings/api by creating an account and requesting API access
    
    with open(config_file, "r") as f:
        config = yaml.safe_load(f)
    
    api_key = config["api_key"]

    tmdb = TMDb()
    tmdb.api_key = api_key 
    tmdb_movie = Movie()

    # Get genres based on Title using TMDB ping
    df['genres'] = df['Title'].map(lambda x: get_genre(str(x), tmdb, tmdb_movie))

    df_sub = df[['Title', 'Cast and crew', 'genres']].copy()

    # Get director's name from "Cast and crew" column
    df_sub['director_name'] = df_sub['Cast and crew'].map(lambda x: get_director(x))
    df_sub['director_name'] = df_sub['director_name'].str.replace(" (director/screenplay);",",")

    # Get actor 1 name
    df_sub['actor_1_name'] = df_sub['Cast and crew'].map(lambda x: get_actor1(x))
    df_sub['actor_1_name'] = df_sub['actor_1_name'].str.replace("Lauren Wolkstein (director); ", "")

    # Get actor 2 name
    df_sub['actor_2_name'] = df_sub['Cast and crew'].map(lambda x: get_actor2(x))

    # Get actor 3 name
    df_sub['actor_3_name'] = df_sub['Cast and crew'].map(lambda x: get_actor3(x))

    # rename title col
    df_sub = df_sub.rename(columns={'Title':'movie_title'})

    # Final Cleaning and preparation
    new_df_sub = df_sub.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
    new_df_sub['actor_1_name'] = new_df_sub['actor_1_name'].replace(np.nan, 'unknown')
    new_df_sub['actor_2_name'] = new_df_sub['actor_2_name'].replace(np.nan, 'unknown')
    new_df_sub['actor_3_name'] = new_df_sub['actor_3_name'].replace(np.nan, 'unknown')
    new_df_sub['movie_title'] = new_df_sub['movie_title'].str.lower()
    new_df_sub['comb'] = new_df_sub['actor_1_name'] + ' ' + new_df_sub['actor_2_name'] + ' '+ new_df_sub['actor_3_name'] + ' '+ new_df_sub['director_name'] +' ' + new_df_sub['genres']

    return new_df_sub

# %% [markdown]
# ### 2018 data

# %%
# Read data from html

link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# Peek into data downloaded from html

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y         12             The Commuter
# 3  J A N U A R Y         12               Proud Mary
# 4  J A N U A R Y         12         Acts of Violence
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2      Lionsgate / StudioCanal / The Picture Company
# 3                                        Screen Gems
# 4                                 Lionsgate Premiere
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Christopher Radcliff (director/screenplay); La...  [3]
# 2  Jaume Collet-Serra (director); Byron Willinger...  [4]
# 3  Babak Najafi (director); John S. Newman, Chris...  [5]
# 4  Brett Donowho (director); Nicolas Aaron Mezzan...  [6]
#      Opening  Opening.1                       Title  \
# 0  A P R I L          6               A Quiet Place
# 1  A P R I L          6                    Blockers
# 2  A P R I L          6  You Were Never Really Here
# 3  A P R I L          6              Chappaquiddick
# 4  A P R I L          6          The Miracle Season
#
#                                   Production company  \
# 0  Paramount Pictures / Platinum Dunes / Sunday N...
# 1  Universal Pictures / Good Universe / Point Gre...
# 2                                     Amazon Studios
# 3                              Entertainment Studios
# 4                                   LD Entertainment
#
#                                        Cast and crew  Ref.
# 0  John Krasinski (director/screenplay); Bryan Wo...  [60]
# 1  Kay Cannon (director); Brian Kehoe, Jim Kehoe ...  [61]
# 2  Lynne Ramsay (director/screenplay); Joaquin Ph...  [62]
# 3  John Curran (director); Taylor Allen, Andrew L...  [63]
# 4  Sean McNamara (director); David Aaron Cohen, E...  [64]
#    Opening  Opening.1                  Title  \
# 0  J U L Y          3  Who's Watching Oliver
# 1  J U L Y          4        The First Purge
# 2  J U L Y          6   Ant-Man and the Wasp
# 3  J U L Y          6    Sorry to Bother You
# 4  J U L Y          6                Whitney
#
#                                   Production company  \
# 0                 Motionpictures / Gravitas Ventures
# 1  Universal Pictures / Blumhouse Productions / P...
# 2                                     Marvel Studios
# 3                                 Annapurna Pictures
# 4                     Roadside Attractions / Miramax
#
#                                        Cast and crew   Ref.
# 0  Richie Moore (director/screenplay); Raimund Hu...  [114]
# 1  Gerard McMurray (director); James DeMonaco (sc...  [115]
# 2  Peyton Reed (director); Chris McKenna, Erik So...  [116]
# 3  Boots Riley (director/screenplay); LaKeith Sta...  [117]
# 4  Kevin Macdonald (director/screenplay); Whitney...  [118]
#          Opening  Opening.1                            Title  \
# 0  O C T O B E R          5                            Venom
# 1  O C T O B E R          5                   A Star Is Born
# 2  O C T O B E R          5  The Great Buster: A Celebration
# 3  O C T O B E R         12                        First Man
# 4  O C T O B E R         12       Bad Times at the El Royale
#
#                                   Production company  \
# 0           Columbia Pictures / Marvel Entertainment
# 1       Warner Bros. Pictures / Peters Entertainment
# 2                                  Cohen Media Group
# 3  Universal Pictures / DreamWorks Pictures / Amb...
# 4                                   20th Century Fox
#
#                                        Cast and crew   Ref.
# 0  Ruben Fleischer (director); Jeff Pinkner, Scot...  [182]
# 1  Bradley Cooper (director/screenplay); Eric Rot...  [183]
# 2            Peter Bogdanovich (director/screenplay)  [184]
# 3  Damien Chazelle (director); Josh Singer (scree...  [185]
# 4  Drew Goddard (director/screenplay); Jeff Bridg...  [186]

# %%
new_df18 = ProcessData(df1, df2, df3, df4, config_file = "config.yml")
new_df18.head()
# Out:
#                             director_name      actor_1_name  \
# 0                            Adam Robitel         Lin Shaye
# 1  Christopher Radcliff, Lauren Wolkstein     Alex Pettyfer
# 2                      Jaume Collet-Serra       Liam Neeson
# 3                            Babak Najafi  Taraji P. Henson
# 4                           Brett Donowho      Bruce Willis
#
#              actor_2_name    actor_3_name                   genres  \
# 0           Angus Sampson  Leigh Whannell          Horror Thriller
# 1  James Freedson-Jackson   Emily Althaus            Drama Mystery
# 2            Vera Farmiga  Patrick Wilson  Action Thriller Mystery
# 3    Jahi Di'Allo Winston     Billy Brown    Thriller Action Crime
# 4             Cole Hauser   Shawn Ashmore    Action Crime Thriller
#
#                movie_title                                               comb
# 0  insidious: the last key  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1         the strange ones  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2             the commuter  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3               proud mary  Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4         acts of violence  Bruce Willis Cole Hauser Shawn Ashmore Brett D...

# %% [markdown]
# ### 2019 data

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# Peek into data downloaded from html

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
# Out:
#          Opening  Opening.1             Title  \
# 0  J A N U A R Y          4       Escape Room
# 1  J A N U A R Y          4        Rust Creek
# 2  J A N U A R Y          4  American Hangman
# 3  J A N U A R Y         11  A Dog's Way Home
# 4  J A N U A R Y         11        The Upside
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
# 3                  Columbia Pictures
# 4                  STX Entertainment
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]
#      Opening  Opening.1                Title  \
# 0  A P R I L          5              Shazam!
# 1  A P R I L          5         Pet Sematary
# 2  A P R I L          5  The Best of Enemies
# 3  A P R I L          5            High Life
# 4  A P R I L          5        Unicorn Store
#
#                                   Production company  \
# 0  Warner Bros. Pictures / New Line Cinema / DC F...
# 1                Paramount Pictures / Room 101, Inc.
# 2                                  STX Entertainment
# 3                  A24 / Arte / ZDF / Canal+ / Ciné+
# 4                                            Netflix
#
#                                        Cast and crew  Ref.
# 0  David F. Sandberg (director); Henry Gayden (sc...  [51]
# 1  Kevin Kolsch, Dennis Widmyer (directors); Jeff...  [52]
# 2  Robin Bissell (director/screenplay); Taraji P....  [53]
# 3  Claire Denis (director/screenplay); Jean-Pol F...  [54]
# 4  Brie Larson (director); Samantha McIntyre (scr...   NaN
#    Opening  Opening.1                        Title  \
# 0  J U L Y          5    Spider-Man: Far From Home
# 1  J U L Y          5  Escape Plan: The Extractors
# 2  J U L Y         12                    Midsommar
# 3  J U L Y         12                       Stuber
# 4  J U L Y         12                        Crawl
#
#                           Production company  \
# 0         Columbia Pictures / Marvel Studios
# 1                       Summit Entertainment
# 2                                        A24
# 3                           20th Century Fox
# 4  Paramount Pictures / Ghost House Pictures
#
#                                        Cast and crew   Ref.
# 0  Jon Watts (director); Chris McKenna, Erik Somm...  [115]
# 1  John Herzfeld (director); John Herzfeld, Miles...  [116]
# 2  Ari Aster (director/screenplay); Florence Pugh...  [117]
# 3  Michael Dowse (director); Tripper Clancy (scre...  [118]
# 4  Alexandre Aja (director); Shawn Rasmussen, Mic...  [119]
#          Opening  Opening.1                Title  \
# 0  O C T O B E R          4                Joker
# 1  O C T O B E R          4      Lucy in the Sky
# 2  O C T O B E R          4  Dolemite Is My Name
# 3  O C T O B E R          4    In the Tall Grass
# 4  O C T O B E R          4             Low Tide
#
#                                   Production company  \
# 0  Warner Bros. Pictures / Village Roadshow Pictu...
# 1                           Fox Searchlight Pictures
# 2                                            Netflix
# 3                                            Netflix
# 4                               A24 / DirecTV Cinema
#
#                                        Cast and crew   Ref.
# 0  Todd Phillips (director/screenplay); Scott Sil...  [171]
# 1  Noah Hawley (director/screenplay); Brian C. Br...  [172]
# 2  Craig Brewer (director); Scott Alexander and L...  [167]
# 3  Vincenzo Natali (director/screenplay); Patrick...    NaN
# 4  Kevin McMullin (director/screenplay); Keean Jo...  [173]

# %%
new_df19 = ProcessData(df1, df2, df3, df4, config_file = "config.yml")
new_df19.head()
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                       genres       movie_title  \
# 0  Deborah Ann Woll      Horror Thriller Mystery       escape room
# 1      Sean O'Bryan  Thriller Drama Action Crime        rust creek
# 2     Oliver Dennis                     Thriller  american hangman
# 3   Alexandra Shipp       Drama Adventure Family  a dog's way home
# 4     Nicole Kidman                 Comedy Drama        the upside
#
#                                                 comb
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2  Donald Sutherland Vincent Kartheiser Oliver De...
# 3  Bryce Dallas Howard Edward James Olmos Alexand...
# 4  Bryan Cranston Kevin Hart Nicole Kidman Neil B...

# %% [markdown]
# ### 2020 data

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# Peek into data downloaded from html

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
# Out:
#          Opening  Opening.1              Title  \
# 0  J A N U A R Y          3         The Grudge
# 1  J A N U A R Y         10         Underwater
# 2  J A N U A R Y         10        Like a Boss
# 3  J A N U A R Y         10      Three Christs
# 4  J A N U A R Y         10  Inherit the Viper
#
#                                   Production company  \
# 0  Screen Gems / Stage 6 Films / Ghost House Pict...
# 1  20th Century Fox / TSG Entertainment / Chernin...
# 2                 Paramount Pictures / Artists First
# 3                                          IFC Films
# 4  Lionsgate / Barry Films / Tycor International ...
#
#                                        Cast and crew Ref.
# 0  Nicolas Pesce (director/screenplay); Andrea Ri...  [2]
# 1  William Eubank (director); Brian Duffield, Ada...  [3]
# 2  Miguel Arteta (director); Sam Pitman, Adam Col...  [4]
# 3  Jon Avnet (director/screenplay); Eric Nazarian...  NaN
# 4  Anthony Jerjen (director); Andrew Crabtree (sc...  [5]
#      Opening  Opening.1                   Title  \
# 0  A P R I L          3         Coffee & Kareem
# 1  A P R I L         10       Trolls World Tour
# 2  A P R I L         10     Love Wedding Repeat
# 3  A P R I L         10          The Main Event
# 4  A P R I L         10  We Summon the Darkness
#
#                           Production company  \
# 0                                    Netflix
# 1  Universal Pictures / DreamWorks Animation
# 2                                    Netflix
# 3                      Netflix / WWE Studios
# 4                                Saban Films
#
#                                        Cast and crew  Ref.
# 0  Michael Dowse (director); Shane McCarthy (scre...  [57]
# 1  Walt Dohrn (director); Jonathan Aibel, Glenn B...  [58]
# 2  Dean Craig (director/screenplay); Olivia Munn,...  [59]
# 3  Jay Karas (director); Larry Postel (screenplay...  [60]
# 4  Marc Meyers (director); Alan Trezza (screenpla...  [61]
#    Opening  Opening.1          Title  \
# 0  J U L Y          3       Hamilton
# 1  J U L Y          3          Relic
# 2  J U L Y          3     Desperados
# 3  J U L Y         10  The Old Guard
# 4  J U L Y         10    Money Plane
#
#                                Production company  \
# 0                  Disney+ / Walt Disney Pictures
# 1  IFC Midnight / Nine Stories Productions / AGBO
# 2                                         Netflix
# 3                        Netflix / Skydance Media
# 4                             Quiver Distribution
#
#                                        Cast and crew   Ref.
# 0  Thomas Kail (director); Lin-Manuel Miranda, Ph...  [103]
# 1  Natalie Erika James (director/screenplay); Chr...  [104]
# 2  LP (director); Ellen Rapoport (screenplay); An...  [105]
# 3  Gina Prince-Bythewood (director); Greg Rucka (...  [106]
# 4  Andrew Lawrence (director/screenplay); Tim Sch...  [107]
#          Opening  Opening.1                   Title  \
# 0  O C T O B E R          2            On the Rocks
# 1  O C T O B E R          2             Spontaneous
# 2  O C T O B E R          2  Vampires vs. the Bronx
# 3  O C T O B E R          2               Possessor
# 4  O C T O B E R          2             Death of Me
#
#                                   Production company  \
# 0                Apple TV+ / A24 / American Zoetrope
# 1  Paramount Pictures / Awesomeness Films / Juras...
# 2                       Netflix / Universal Pictures
# 3  Neon / Well Go USA Entertainment / Elevation P...
# 4                                        Saban Films
#
#                                        Cast and crew   Ref.
# 0  Sofia Coppola (director/screenplay); Rashida J...  [169]
# 1  Brian Duffield (director/screenplay); Katherin...  [170]
# 2  Osmany Rodriguez (director/screenplay); Blaise...  [171]
# 3  Brandon Cronenberg (director/screenplay); Andr...  [172]
# 4  Darren Lynn Bousman (director); Arli Margolis,...  [173]

# %%
new_df20 = ProcessData(df1, df2, df3, df4, config_file = "config.yml")
new_df20.head()
# Out:
#     director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0   Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1  William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2   Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3       Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4  Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
#
#                                     genres        movie_title  \
# 0                  Horror Mystery Thriller         the grudge
# 1  Horror Science Fiction Action Adventure         underwater
# 2                                   Comedy        like a boss
# 3                                    Drama      three christs
# 4                     Crime Thriller Drama  inherit the viper
#
#                                                 comb
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# 1  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4  Josh Hartnett Margarita Levieva Chandler Riggs...

# %% [markdown]
# ### 2021 data

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# Peek into data downloaded from html

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
# Out:
#          Opening  Opening.1                            Title  \
# 0  J A N U A R Y          1              Shadow in the Cloud
# 1  J A N U A R Y          5                          Hacksaw
# 2  J A N U A R Y         12  Dr. Bird's Advice for Sad Poets
# 3  J A N U A R Y         13                  The White Tiger
# 4  J A N U A R Y         14                      Locked Down
#
#                          Production company  \
# 0                    Vertical Entertainment
# 1          Leone Films / Midnight Releasing
# 2  Relativity Media / Ketchup Entertainment
# 3  Netflix / ARRAY / Purple Pebble Pictures
# 4           HBO Max / Warner Bros. Pictures
#
#                                        Cast and crew Ref.
# 0  Roseanne Liang (director/screenplay); Max Land...  [2]
# 1  Anthony Leone (director/screenplay); Amy Cay, ...  [3]
# 2  Yaniv Raz (director/screenplay); Lucas Jade Zu...  [4]
# 3  Ramin Bahrani (director/screenplay); Adarsh Go...  NaN
# 4  Doug Liman (director); Steven Knight (screenpl...  [5]
#      Opening  Opening.1                              Title  \
# 0  A P R I L          2                    Concrete Cowboy
# 1  A P R I L          2                         The Unholy
# 2  A P R I L          2              Every Breath You Take
# 3  A P R I L          2                         Shiva Baby
# 4  A P R I L          2  The Girl Who Believes in Miracles
#
#                    Production company  \
# 0                             Netflix
# 1  Screen Gems / Ghost House Pictures
# 2              Vertical Entertainment
# 3                              Utopia
# 4          Atlas Distribution Company
#
#                                        Cast and crew  Ref.
# 0  Ricky Staub (director/screenplay); Dan Walser ...  [60]
# 1  Evan Spiliotopoulos (director/screenplay); Jef...  [61]
# 2  Vaughn Stein (director); David Murray (screenp...  [62]
# 3  Emma Seligman (director/screenplay); Rachel Se...   NaN
# 4  Richard Correll (director/screenplay); G.M. Me...   NaN
#    Opening  Opening.1                           Title  \
# 0  J U L Y          1                  No Sudden Move
# 1  J U L Y          2                The Tomorrow War
# 2  J U L Y          2  The Boss Baby: Family Business
# 3  J U L Y          2               The Forever Purge
# 4  J U L Y          2      Fear Street Part One: 1994
#
#                                   Production company  \
# 0                    HBO Max / Warner Bros. Pictures
# 1  Amazon Studios / Paramount Pictures / Skydance...
# 2  Universal Pictures / DreamWorks Animation / Pe...
# 3  Universal Pictures / Platinum Dunes / Blumhous...
# 4                    Netflix / Chernin Entertainment
#
#                                        Cast and crew   Ref.
# 0  Steven Soderbergh (director); Ed Solomon (scre...  [113]
# 1  Chris McKay (director); Zach Dean (screenplay)...  [114]
# 2  Tom McGrath (director); Michael McCullers (scr...  [115]
# 3  Everardo Gout (director); James DeMonaco (scre...  [116]
# 4  Leigh Janiak (director/screenplay); Phil Grazi...    NaN
#          Opening  Opening.1                        Title  \
# 0  O C T O B E R        1.0  Venom: Let There Be Carnage
# 1  O C T O B E R        1.0    The Many Saints of Newark
# 2  O C T O B E R        1.0          The Addams Family 2
# 3  O C T O B E R        1.0                   Bingo Hell
# 4  O C T O B E R        1.0               Black as Night
#
#                                   Production company  \
# 0  Columbia Pictures / Marvel Entertainment / Ten...
# 1  Warner Bros. Pictures / New Line Cinema / HBO ...
# 2                Metro-Goldwyn-Mayer / Bron Creative
# 3              Amazon Studios / Blumhouse Television
# 4              Amazon Studios / Blumhouse Television
#
#                                        Cast and crew   Ref.
# 0  Andy Serkis (director), Kelly Marcel (screenpl...  [204]
# 1  Alan Taylor (director); David Chase, Lawrence ...  [191]
# 2  Conrad Vernon, Greg Tiernan (directors); Dan H...  [205]
# 3  Gigi Saul Guerrero (director/screenplay); Shan...  [206]
# 4  Maritte Lee Go (director); Sherman Payne (scre...  [206]

# %%
new_df21 = ProcessData(df1, df2, df3, df4, config_file = "config.yml")
new_df21.head()
# Out:
#     director_name        actor_1_name          actor_2_name  \
# 0  Roseanne Liang  Chloë Grace Moretz     Taylor John Smith
# 1   Anthony Leone             Amy Cay  Brian Patrick Butler
# 2       Yaniv Raz   Lucas Jade Zumann        Taylor Russell
# 3   Ramin Bahrani       Adarsh Gourav         Rajkummar Rao
# 4      Doug Liman       Anne Hathaway      Chiwetel Ejiofor
#
#             actor_3_name                             genres  \
# 0           Beulah Koale                  Horror Action War
# 1     Michael C. Burgess  Adventure Family TV Movie Western
# 2           Chase Stokes                       Comedy Drama
# 3  Priyanka Chopra Jonas                              Drama
# 4       Stephen Merchant               Comedy Crime Romance
#
#                        movie_title  \
# 0              shadow in the cloud
# 1                          hacksaw
# 2  dr. bird's advice for sad poets
# 3                  the white tiger
# 4                      locked down
#
#                                                 comb
# 0  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1  Amy Cay Brian Patrick Butler Michael C. Burges...
# 2  Lucas Jade Zumann Taylor Russell Chase Stokes ...
# 3  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 4  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...

# %% [markdown]
# ### 2022 data

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# Peek into data downloaded from html

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
# Out:
#          Opening  Opening.1                     Title  \
# 0  J A N U A R Y          7                   The 355
# 1  J A N U A R Y          7  The Legend of La Llorona
# 2  J A N U A R Y          7              The Commando
# 3  J A N U A R Y          7            American Siege
# 4  J A N U A R Y         14                    Scream
#
#                                   Production company  \
# 0  Universal Pictures / Freckle Films / FilmNatio...
# 1                     Saban Films / Ageless Pictures
# 2               Saban Films / Premiere Entertainment
# 3                             Vertical Entertainment
# 4  Paramount Pictures / Spyglass Media Group / Ra...
#
#                                        Cast and crew Ref.
# 0  Simon Kinberg (director/screenplay); Theresa R...  [2]
# 1  Patricia Harris Seeley (director); José Prende...  [3]
# 2  Asif Akbar (director); Koji Steven Sakai (scre...  [4]
# 3  Edward John Drake (director/screenplay); Timot...  [5]
# 4  Matt Bettinelli-Olpin, Tyler Gillett (director...  [6]
#      Opening  Opening.1                                 Title  \
# 0  A P R I L          1                               Morbius
# 1  A P R I L          1                            The Bubble
# 2  A P R I L          1                        The Contractor
# 3  A P R I L          1                 Better Nate Than Ever
# 4  A P R I L          1  Apollo 10 1⁄2: A Space Age Childhood
#
#                                   Production company  \
# 0  Columbia Pictures / Marvel Entertainment / A2 ...
# 1                       Netflix / Apatow Productions
# 2  Paramount Pictures / STXfilms / Thunder Road F...
# 3                     Disney+ / Walt Disney Pictures
# 4                        Netflix / Netflix Animation
#
#                                        Cast and crew  Ref.
# 0  Daniel Espinosa (director); Matt Sazama, Burk ...  [65]
# 1  Judd Apatow (director/screenplay); Pam Brady (...  [66]
# 2  Tarik Saleh (director); J. P. Davis (screenpla...  [67]
# 3  Tim Federle (director/screenplay); Aria Brooks...  [68]
# 4  Richard Linklater (director/screenplay); Glen ...  [69]
#    Opening  Opening.1                     Title  \
# 0  J U L Y          1  Minions: The Rise of Gru
# 1  J U L Y          1              The Forgiven
# 2  J U L Y          1        Mr. Malcolm's List
# 3  J U L Y          1              The Princess
# 4  J U L Y          1                  Hot Seat
#
#                                   Production company  \
# 0                  Universal Pictures / Illumination
# 1  Roadside Attractions / Vertical Entertainment ...
# 2     Bleecker Street / Ingenious Media / Refinery29
# 3        Hulu / 20th Century Studios / Original Film
# 4                                          Lionsgate
#
#                                        Cast and crew   Ref.
# 0  Kyle Balda (director); Matthew Fogel (screenpl...  [125]
# 1  John Michael McDonagh (director/screenplay); R...  [126]
# 2  Emma Holly Jones (director); Suzanne Allain (s...  [127]
# 3  Le-Van Kiet (director); Ben Lustig, Jake Thorn...  [128]
# 4  James Cullen Bressack (director); Collin Watts...  [129]
#          Opening  Opening.1                  Title  \
# 0  O C T O B E R        2.0   Mr. Harrigan's Phone
# 1  O C T O B E R        4.0            Terrifier 2
# 2  O C T O B E R        7.0  Lyle, Lyle, Crocodile
# 3  O C T O B E R        7.0              Amsterdam
# 4  O C T O B E R        7.0                    Tár
#
#                                   Production company  \
# 0                    Netflix / Blumhouse Productions
# 1  Bloody Disgusting / Fuzz on the Lens Productio...
# 2              Columbia Pictures / TSG Entertainment
# 3         20th Century Studios / Regency Enterprises
# 4                                     Focus Features
#
#                                        Cast and crew   Ref.
# 0  John Lee Hancock (director/screenplay); Donald...  [180]
# 1  Damien Leone (director/screenplay); Lauren LaV...  [200]
# 2  Will Speck, Josh Gordon (directors); William D...  [201]
# 3  David O. Russell (director/screenplay); Christ...  [202]
# 4  Todd Field (director/screenplay); Cate Blanche...  [203]

# %%
new_df22 = ProcessData(df1, df2, df3, df4, config_file = "config.yml")
new_df22.head()
# Out:
#                           director_name       actor_1_name       actor_2_name  \
# 0                         Simon Kinberg   Jessica Chastain      Penélope Cruz
# 1                Patricia Harris Seeley      Autumn Reeser        Danny Trejo
# 2                            Asif Akbar      Mickey Rourke  Michael Jai White
# 3                     Edward John Drake  Timothy V. Murphy       Bruce Willis
# 4  Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera      Mason Gooding
#
#    actor_3_name                           genres               movie_title  \
# 0  Fan Bingbing        Action Adventure Thriller                   the 355
# 1  Antonio Cupo  Family Animation Fantasy Horror  the legend of la llorona
# 2       unknown            Action Crime Thriller              the commando
# 3     Rob Gough        Action Adventure Thriller            american siege
# 4  Jenna Ortega          Horror Mystery Thriller                    scream
#
#                                                 comb
# 0  Jessica Chastain Penélope Cruz Fan Bingbing Si...
# 1  Autumn Reeser Danny Trejo Antonio Cupo Patrici...
# 2  Mickey Rourke Michael Jai White unknown Asif A...
# 3  Timothy V. Murphy Bruce Willis Rob Gough Edwar...
# 4  Melissa Barrera Mason Gooding Jenna Ortega Mat...

# %% [markdown]
# ### 2023 data

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# Peek into data downloaded from html

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
# Out:
#          Opening  Opening.1                 Title  \
# 0  J A N U A R Y          6                 M3GAN
# 1  J A N U A R Y          6           The Old Way
# 2  J A N U A R Y         11  The Devil Conspiracy
# 3  J A N U A R Y         13                 Plane
# 4  J A N U A R Y         13           House Party
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / A...
# 1                         Saban Films / Saturn Films
# 2                               Samuel Goldwyn Films
# 3  Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4            Warner Bros. Pictures / New Line Cinema
#
#                                        Cast and crew Ref.
# 0  Gerard Johnstone (director); Akela Cooper (scr...  [3]
# 1  Brett Donowho (director); Carl W. Lucas (scree...  [4]
# 2  Nathan Frankowski (director); Ed Alan (screenp...  [5]
# 3  Jean-François Richet (director); Charles Cummi...  [6]
# 4  Calmatic (director); Jamal Olori, Stephen Glov...  [7]
#      Opening  Opening.1                        Title  \
# 0  A P R I L          4        Miracle at Manchester
# 1  A P R I L          5  The Super Mario Bros. Movie
# 2  A P R I L          5                          Air
# 3  A P R I L          7                  Praise This
# 4  A P R I L          7                   Showing Up
#
#                                   Production company  \
# 0                       Bridgestone Media / JC Films
# 1       Universal Pictures / Illumination / Nintendo
# 2  Amazon Studios / Skydance Media / Mandalay Pic...
# 3  Peacock / Universal Pictures / Will Packer Pro...
# 4                                                A24
#
#                                        Cast and crew  Ref.
# 0  Eddie McClintock (director); Jason Campbell (s...  [72]
# 1  Aaron Horvath, Michael Jelenic (directors); Ma...  [73]
# 2  Ben Affleck (director); Alex Convery (screenpl...  [74]
# 3  Tina Gordon Chism (director/screenplay); Camil...  [75]
# 4  Kelly Reichardt (director/screenplay); Jonatha...  [76]
#    Opening  Opening.1                    Title  \
# 0  J U L Y          4         Sound of Freedom
# 1  J U L Y          7  Insidious: The Red Door
# 2  J U L Y          7                 Joy Ride
# 3  J U L Y          7             The Out-Laws
# 4  J U L Y          7               Earth Mama
#
#                                   Production company  \
# 0                     Angel Studios / Santa Fe Films
# 1  Screen Gems / Stage 6 Films / Blumhouse Produc...
# 2                    Lionsgate / Point Grey Pictures
# 3                Netflix / Happy Madison Productions
# 4            A24 / Film4 Productions / Academy Films
#
#                                        Cast and crew   Ref.
# 0  Alejandro Monteverde (director/screenplay); Ro...  [150]
# 1  Patrick Wilson (director); Scott Teems (screen...  [151]
# 2  Adele Lim (director); Cherry Chevapravatdumron...  [152]
# 3  Tyler Spindel (director); Evan Turner, Ben Zaz...  [153]
# 4  Savanna Leaf (director/screenplay); Tia Nomore...  [154]
#          Opening  Opening.1                     Title  \
# 0  O C T O B E R          1                    Oracle
# 1  O C T O B E R          2                 Appendage
# 2  O C T O B E R          6    The Exorcist: Believer
# 3  O C T O B E R          6  Pet Sematary: Bloodlines
# 4  O C T O B E R          6            Totally Killer
#
#                                   Production company  \
# 0  Max / Universal Pictures / Will Packer Product...
# 1                         Hulu / 20th Digital Studio
# 2  Universal Pictures / Blumhouse Productions / M...
# 3  Paramount+ / Paramount Players / Di Bonaventur...
# 4             Amazon Studios / Blumhouse Productions
#
#                                        Cast and crew   Ref.
# 0  Daniel Di Grado (director); Michael Ross, Core...  [228]
# 1  Anna Zlokovic (director/screenplay); Hadley Ro...  [229]
# 2  David Gordon Green (director/screenplay); Pete...  [230]
# 3  Lindsey Anderson Beer (director/screenplay); J...  [231]
# 4  Nahnatchka Khan (director); David Matalon, Sas...  [232]

# %%
new_df23 = ProcessData(df1, df2, df3, df4, config_file = "config.yml")
new_df23.head()
# Out:
#           director_name      actor_1_name          actor_2_name  actor_3_name  \
# 0      Gerard Johnstone  Allison Williams         Violet McGraw   Amie Donald
# 1         Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong       unknown
# 2     Nathan Frankowski   Alice Orr-Ewing             Joe Doyle  Eveline Hall
# 3  Jean-François Richet     Gerard Butler           Mike Colter      Yoson An
# 4              Calmatic        Tosin Cole        Jacob Latimore  Karen Obilom
#
#                                     genres           movie_title  \
# 0                   Science Fiction Horror                 m3gan
# 1                            Western Drama           the old way
# 2  Horror Fantasy Science Fiction Thriller  the devil conspiracy
# 3                Action Adventure Thriller                 plane
# 4                                   Comedy           house party
#
#                                                 comb
# 0  Allison Williams Violet McGraw Amie Donald Ger...
# 1  Nicolas Cage Ryan Kiera Armstrong unknown Bret...
# 2  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 3  Gerard Butler Mike Colter Yoson An Jean-Franço...
# 4  Tosin Cole Jacob Latimore Karen Obilom Calmati...

# %%
df_latest = pd.concat([new_df23, new_df22, new_df21, new_df20, new_df19, new_df18], axis = 0, ignore_index=True)
df_latest.head()
# Out:
#           director_name      actor_1_name          actor_2_name  actor_3_name  \
# 0      Gerard Johnstone  Allison Williams         Violet McGraw   Amie Donald
# 1         Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong       unknown
# 2     Nathan Frankowski   Alice Orr-Ewing             Joe Doyle  Eveline Hall
# 3  Jean-François Richet     Gerard Butler           Mike Colter      Yoson An
# 4              Calmatic        Tosin Cole        Jacob Latimore  Karen Obilom
#
#                                     genres           movie_title  \
# 0                   Science Fiction Horror                 m3gan
# 1                            Western Drama           the old way
# 2  Horror Fantasy Science Fiction Thriller  the devil conspiracy
# 3                Action Adventure Thriller                 plane
# 4                                   Comedy           house party
#
#                                                 comb
# 0  Allison Williams Violet McGraw Amie Donald Ger...
# 1  Nicolas Cage Ryan Kiera Armstrong unknown Bret...
# 2  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 3  Gerard Butler Mike Colter Yoson An Jean-Franço...
# 4  Tosin Cole Jacob Latimore Karen Obilom Calmati...

# %%
df_old = pd.read_csv('./new_data.csv')
df_old.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...

# %%
df_final = pd.concat([df_latest, df_old], axis=0, ignore_index = True)

# %%
df_final.shape
# Out:
# (7158, 7)

# %%
# Delete duplicate records
df_final.drop_duplicates(subset = "movie_title", keep = 'last', inplace=True)

# %%
# Check for missing values
df_final.isnull().sum()
# Out:
# director_name    29
# actor_1_name      0
# actor_2_name      0
# actor_3_name      0
# genres            1
# movie_title       0
# comb             30
# dtype: int64

# %%
# Drop records with missing values
df_final = df_final.dropna(how='any')

# %%
# Check for missing values
df_final.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
df_final.to_csv('./main_data.csv',index=False)

# %% [markdown]
# ### OLD CODE

# %%
# # Append all 4 dataframes together

# df = pd.concat([df1, df2, df3, df4], axis = 0, ignore_index=True)

# %%
# df.head()

# %%
# # Get TMDB API key
# # get your API Key here: https://www.themoviedb.org/settings/api by creating an account and requesting API access

# with open("config.yml", "r") as f:
#     config = yaml.safe_load(f)

# api_key = config["api_key"]

# %%
# tmdb = TMDb()
# tmdb.api_key = api_key

# %%
# tmdb_movie = Movie()
# def get_genre(x): #pass in the title of the movies
#     genres = []
#     result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
#     movie_id = result[0].id #we will match the "id" with the "title"
#     response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
#     data_json = response.json() #we will then convert it to a json file
#     if data_json['genres']: #in the json file we will only need to extract the "genre"
#         genre_str = " " 
#         for i in range(0,len(data_json['genres'])):
#             genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
#         return genre_str.join(genres)
#     else:
#         np.NaN # we will return the results but if we don't find anything we will consider it as a missing value

# %%
# df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
# df.head()

# %%
# # Subset to only required columns

# df_2018 = df[['Title', 'Cast and crew', 'genres']].copy()
# df_2018.head()

# %%
# # Function to get directors name

# def get_director(x):
#     if " (director)" in x: # we are getting "director"
#         return x.split(" (director)")[0]
#     elif " (directors)" in x: # we are getting "directors" with "s"
#         return x.split(" (directors)")[0]
#     elif " (director[" in x:
#         return x.split(" (director[")[0]
#     elif " (director/" in x:
#         return x.split(" (director/")[0] # we are getting "director/screenplay"

# %%
# #let's apply the above function on the "Cast and crew" column
# df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# df_2018.head()

# %%
# df_2018['director_name'] = df_2018['director_name'].str.replace(" (director/screenplay);",",")

# %%
# df_2018.head()

# %%
# def get_actor1(x):
#     return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
# df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# df_2018.head()

# %%
# df_2018['actor_1_name'] =df_2018['actor_1_name'].str.replace("Lauren Wolkstein (director); ", "")

# %%
# def get_actor2(x):
#     if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
#         return np.NaN
#     else:
#         return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
# df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# df_2018.head()

# %%
# def get_actor3(x):
#     if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
#         return np.NaN
#     else:
#         return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
# df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# df_2018.head()

# %%
# df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
# new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
# new_df18.head()

# %%
# new_df18['actor_1_name'] = new_df18['actor_1_name'].replace(np.nan, 'unknown')
# new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
# new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')
# new_df18['movie_title'] = new_df18['movie_title'].str.lower()
# new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
# new_df18.head()
